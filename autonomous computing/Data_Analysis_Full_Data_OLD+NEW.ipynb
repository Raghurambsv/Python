# %%
import pandas as pd
import numpy as np
import time
import datetime
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/Users/janaki.p/Documents/Expert_Admin/OLD_NEW_Processed_data.csv')

# %%
df.dtypes
# Out:
# Unnamed: 0              int64
# CASE_ID                 int64
# CHANNEL_NAME           object
# CONTACT_OPTION         object
# CUST_REGION_NAME       object
# DIAL_SCHEDULE_TIME    float64
# HISTORY_DATA           object
# IP_ADDRESS             object
# RESULT                 object
# SCB_TIME               object
# SCR_DATE               object
# UUID                   object
# Unnamed: 0.1          float64
# Schedule_time          object
# Date_SC                object
# Time_SC                object
# year                    int64
# month                   int64
# day                     int64
# hour                    int64
# Minutes                 int64
# Seconds                 int64
# weekday                 int64
# dtype: object

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'CASE_ID', 'CHANNEL_NAME', 'CONTACT_OPTION',
#        'CUST_REGION_NAME', 'DIAL_SCHEDULE_TIME', 'HISTORY_DATA', 'IP_ADDRESS',
#        'RESULT', 'SCB_TIME', 'SCR_DATE', 'UUID', 'Unnamed: 0.1',
#        'Schedule_time', 'Date_SC', 'Time_SC', 'year', 'month', 'day', 'hour',
#        'Minutes', 'Seconds', 'weekday'],
#       dtype='object')

# %%
df=df.drop(columns=['Unnamed: 0','Unnamed: 0.1'])

# %%
#df=df.drop(columns=['HISTORY_DATA','IP_ADDRESS'])

# %%
df['Schedule_time']=pd.to_datetime(df['Schedule_time'])

# %%
df=df.set_index(['Schedule_time'])

# %%
df
# Out:
#                             CASE_ID CHANNEL_NAME CONTACT_OPTION  \
# Schedule_time
# 2019-01-30 20:22:30    100747980538          CAS        NEW_SCB
# 2019-01-31 00:04:36    100747090236         CHAT        NEW_SCB
# 2019-01-31 07:32:41    100747955351         CHAT        NEW_SCB
# 2019-01-31 16:51:34    100747980638          CAS        NEW_SCB
# 2019-01-30 21:37:31    100747980641          CAS        NEW_SCB
# 2019-01-30 18:33:40    100747880271        AGENT        NEW_SCB
# 2019-01-30 18:33:37    100747962717        AGENT        NEW_SCB
# 2019-01-31 17:06:15    100747903698        AGENT        NEW_SCB
# 2019-01-31 01:18:44    100747980714          CAS        NEW_SCB
# 2019-01-30 22:36:01    100747980721       IOSAPP        NEW_SCB
# 2019-01-31 15:06:01    100747980785          CAS        NEW_SCB
# 2019-01-30 23:06:00    100747970521        AGENT        NEW_SCB
# 2019-01-30 18:30:15    100747980832          CMA        NEW_SCB
# ...

# %%
df['Date_SC']=pd.to_datetime(df['Date_SC'])

# %%
#df=df.set_index(['Date_SC'])

# %%
df['Time_SC']=pd.to_datetime(df['Time_SC'])

# %%
y=df['day'].resample('7D').count()

# %%
y
# Out:
# Schedule_time
# 2019-01-30 18:30:15    167760
# 2019-02-06 18:30:15    179051
# 2019-02-13 18:30:15    171245
# 2019-02-20 18:30:15     18836
# 2019-02-27 18:30:15        52
# 2019-03-06 18:30:15         0
# 2019-03-13 18:30:15         0
# 2019-03-20 18:30:15     68912
# 2019-03-27 18:30:15    160616
# 2019-04-03 18:30:15    156473
# 2019-04-10 18:30:15     86439
# 2019-04-17 18:30:15       885
# 2019-04-24 18:30:15         2
# Name: day, dtype: int64

# %%
a4_dims = (10, 10)
fig, ax = plt.subplots(figsize=a4_dims)
y.plot(ax=ax)

# %%
df.columns
# Out:
# Index(['CASE_ID', 'CHANNEL_NAME', 'CONTACT_OPTION', 'CUST_REGION_NAME',
#        'DIAL_SCHEDULE_TIME', 'HISTORY_DATA', 'IP_ADDRESS', 'RESULT',
#        'SCB_TIME', 'SCR_DATE', 'UUID', 'Date_SC', 'Time_SC', 'year', 'month',
#        'day', 'hour', 'Minutes', 'Seconds', 'weekday'],
#       dtype='object')

# %%
a4_dims = (15, 5)
fig, ax = plt.subplots(figsize=a4_dims)
y=df['day'].resample('D').count()
y.plot()

# %%
a4_dims = (15, 5)
fig, ax = plt.subplots(figsize=a4_dims)
y=df['day'].resample('3T').count()
y.plot(ax=ax)

# %%
a4_dims = (15, 5)
fig, ax = plt.subplots(figsize=a4_dims)
y=df['day'].resample('15T').count()
y.plot(ax=ax)

# %%
a4_dims = (15, 5)
fig, ax = plt.subplots(figsize=a4_dims)
sns.countplot(x='CHANNEL_NAME',data=df,ax=ax)

# %%
a4_dims = (15, 5)
fig, ax = plt.subplots(figsize=a4_dims)
sns.countplot(x='CUST_REGION_NAME',data=df,ax=ax)

# %%
a4_dims = (15, 5)
fig, ax = plt.subplots(figsize=a4_dims)
sns.countplot(x='CHANNEL_NAME',hue='CUST_REGION_NAME',data=df,ax=ax)

# %%
a4_dims = (15, 5)
fig, ax = plt.subplots(figsize=a4_dims)
sns.countplot(x='CONTACT_OPTION',data=df,ax=ax)

# %%
a4_dims = (15, 5)
fig, ax = plt.subplots(figsize=a4_dims)
sns.countplot(x='weekday',data=df,ax=ax)

# %%
df.weekday.value_counts()
# Out:
# 1    169971
# 2    163059
# 3    155238
# 4    148241
# 0    136798
# 5    133136
# 6    103828
# Name: weekday, dtype: int64

# %%
df.CONTACT_OPTION.value_counts()
# Out:
# NEW_SCB    985072
# RES_SCB     25199
# Name: CONTACT_OPTION, dtype: int64

# %%
y=df['day'].resample('D').count()
print(y)
y.plot()
# Out:
# Schedule_time
# 2019-01-30     3523
# 2019-01-31    22413
# 2019-02-01    27458
# 2019-02-02    24068
# 2019-02-03    20409
# 2019-02-04    22884
# 2019-02-05    23475
# 2019-02-06    29056
# 2019-02-07    28219
# 2019-02-08    26057
# 2019-02-09    24450
# 2019-02-10    20652
# 2019-02-11    27318
# 2019-02-12    26664
# 2019-02-13    25423
# 2019-02-14    24564
# 2019-02-15    24580
# 2019-02-16    23392
# 2019-02-17    20132
# 2019-02-18    27179
# 2019-02-19    25904
# 2019-02-20    25381
# 2019-02-21    10249
# 2019-02-22     1603
# 2019-02-23     1015
# 2019-02-24      354
# 2019-02-25      286
# 2019-02-26      134
# 2019-02-27       58
# 2019-02-28       10
#               ...
# 2019-03-29    22660
# 2019-03-30    20093
# 2019-03-31    17667
# 2019-04-01    26638
# 2019-04-02    25077
# 2019-04-03    24537
# 2019-04-04    23880
# 2019-04-05    23365
# 2019-04-06    20373
# 2019-04-07    17606
# 2019-04-08    24134
# 2019-04-09    23632
# 2019-04-10    23272
# ...

# %%
y=y['2019-02-01':'2019-02-28']
print(y)
y.plot()
# Out:
# Schedule_time
# 2019-02-01    27458
# 2019-02-02    24068
# 2019-02-03    20409
# 2019-02-04    22884
# 2019-02-05    23475
# 2019-02-06    29056
# 2019-02-07    28219
# 2019-02-08    26057
# 2019-02-09    24450
# 2019-02-10    20652
# 2019-02-11    27318
# 2019-02-12    26664
# 2019-02-13    25423
# 2019-02-14    24564
# 2019-02-15    24580
# 2019-02-16    23392
# 2019-02-17    20132
# 2019-02-18    27179
# 2019-02-19    25904
# 2019-02-20    25381
# 2019-02-21    10249
# 2019-02-22     1603
# 2019-02-23     1015
# 2019-02-24      354
# 2019-02-25      286
# 2019-02-26      134
# 2019-02-27       58
# 2019-02-28       10
# Freq: D, Name: day, dtype: int64

# %%
y=df['Date_SC'].resample('D').count()

# %%
y=y['2019-02-01':'2019-02-28']

# %%
y.plot()

# %%
y=df['Date_SC'].resample('7D').count()
y.plot()

# %%
y=df['Time_SC'].resample('H').count()
y=y['2019-04-01 00:00:00':'2019-04-01 23:59:00']
y.plot()

# %%
y=df['Time_SC'].resample('H').count()
y=y['2019-02-01 00:00:00':'2019-02-01 23:59:00']
y.plot()

# %%
y=df['Date_SC'].resample('H').count()
#y=y['2019-02-01':'2019-02-15']
y.plot()

# %%
y=df['Time_SC'].resample('H').count()
y=y['2019-02-01 00:00:00':'2019-02-01 23:59:00']
y.plot()

# %%
y=df['Time_SC'].resample('H').count()
y=y['2019-02-02 00:00:00':'2019-02-02 23:59:00']
y.plot()

# %%
y=df['Time_SC'].resample('H').count()
y=y['2019-02-03 00:00:00':'2019-02-03 23:59:00']
y.plot()

# %%
col=['Time_SC','Date_SC','CHANNEL_NAME','CUST_REGION_NAME']
df1=df[col]

# %%
df1
# Out:
#                                 Time_SC    Date_SC CHANNEL_NAME  \
# Schedule_time
# 2019-01-30 20:22:30 2019-04-16 20:22:30 2019-01-30          CAS
# 2019-01-31 00:04:36 2019-04-16 00:04:36 2019-01-31         CHAT
# 2019-01-31 07:32:41 2019-04-16 07:32:41 2019-01-31         CHAT
# 2019-01-31 16:51:34 2019-04-16 16:51:34 2019-01-31          CAS
# 2019-01-30 21:37:31 2019-04-16 21:37:31 2019-01-30          CAS
# 2019-01-30 18:33:40 2019-04-16 18:33:40 2019-01-30        AGENT
# 2019-01-30 18:33:37 2019-04-16 18:33:37 2019-01-30        AGENT
# 2019-01-31 17:06:15 2019-04-16 17:06:15 2019-01-31        AGENT
# 2019-01-31 01:18:44 2019-04-16 01:18:44 2019-01-31          CAS
# 2019-01-30 22:36:01 2019-04-16 22:36:01 2019-01-30       IOSAPP
# 2019-01-31 15:06:01 2019-04-16 15:06:01 2019-01-31          CAS
# 2019-01-30 23:06:00 2019-04-16 23:06:00 2019-01-30        AGENT
# 2019-01-30 18:30:15 2019-04-16 18:30:15 2019-01-30          CMA
# ...

# %%
#y=df1['Date_SC'].resample('D').count()
y=df1['Time_SC'].resample('D').count()

# %%
y1=df1['Time_SC'].resample('H').count()

# %%
type(y1)
# Out:
# pandas.core.series.Series

# %%
df2=y
print(df2)
# Out:
# Schedule_time
# 2019-01-30     3523
# 2019-01-31    22413
# 2019-02-01    27458
# 2019-02-02    24068
# 2019-02-03    20409
# 2019-02-04    22884
# 2019-02-05    23475
# 2019-02-06    29056
# 2019-02-07    28219
# 2019-02-08    26057
# 2019-02-09    24450
# 2019-02-10    20652
# 2019-02-11    27318
# 2019-02-12    26664
# 2019-02-13    25423
# 2019-02-14    24564
# 2019-02-15    24580
# 2019-02-16    23392
# 2019-02-17    20132
# 2019-02-18    27179
# 2019-02-19    25904
# 2019-02-20    25381
# 2019-02-21    10249
# 2019-02-22     1603
# 2019-02-23     1015
# 2019-02-24      354
# 2019-02-25      286
# 2019-02-26      134
# 2019-02-27       58
# 2019-02-28       10
#               ...
# 2019-03-29    22660
# 2019-03-30    20093
# 2019-03-31    17667
# 2019-04-01    26638
# 2019-04-02    25077
# 2019-04-03    24537
# 2019-04-04    23880
# 2019-04-05    23365
# 2019-04-06    20373
# 2019-04-07    17606
# 2019-04-08    24134
# 2019-04-09    23632
# 2019-04-10    23272
# ...

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
result = seasonal_decompose(df2, model='additive')
result.plot()

# %%
y=df.Time_SC.resample('H').count()

# %%
y
# Out:
# Schedule_time
# 2019-01-30 18:00:00     111
# 2019-01-30 19:00:00     485
# 2019-01-30 20:00:00     654
# 2019-01-30 21:00:00     696
# 2019-01-30 22:00:00     777
# 2019-01-30 23:00:00     800
# 2019-01-31 00:00:00     977
# 2019-01-31 01:00:00    1229
# 2019-01-31 02:00:00    1026
# 2019-01-31 03:00:00     475
# 2019-01-31 04:00:00     283
# 2019-01-31 05:00:00     351
# 2019-01-31 06:00:00     332
# 2019-01-31 07:00:00     653
# 2019-01-31 08:00:00     871
# 2019-01-31 09:00:00    1059
# 2019-01-31 10:00:00    1336
# 2019-01-31 11:00:00    1044
# 2019-01-31 12:00:00     643
# 2019-01-31 13:00:00    1238
# 2019-01-31 14:00:00    1097
# 2019-01-31 15:00:00    1211
# 2019-01-31 16:00:00    1349
# 2019-01-31 17:00:00    1338
# 2019-01-31 18:00:00     990
# 2019-01-31 19:00:00     854
# 2019-01-31 20:00:00     991
# 2019-01-31 21:00:00     996
# 2019-01-31 22:00:00    1056
# 2019-01-31 23:00:00    1014
#                        ...
# 2019-04-26 18:00:00       0
# ...

# %%
y=y['2019-02-01':'2019-02-27']
result = seasonal_decompose(y, model='additive')
result.plot()

# %%
# grid search sarima hyperparameters for monthly mean temp dataset
from math import sqrt
from multiprocessing import cpu_count
from joblib import Parallel
from joblib import delayed
from warnings import catch_warnings
from warnings import filterwarnings
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.metrics import mean_squared_error
from pandas import read_csv

# one-step sarima forecast
def sarima_forecast(history, config):
	order, sorder, trend = config
	# define model
	model = SARIMAX(history, order=order, seasonal_order=sorder, trend=trend, enforce_stationarity=False, enforce_invertibility=False)
	# fit model
	model_fit = model.fit(disp=False)
	# make one step forecast
	yhat = model_fit.predict(len(history), len(history))
	return yhat[0]

# root mean squared error or rmse
def measure_rmse(actual, predicted):
	return sqrt(mean_squared_error(actual, predicted))

# split a univariate dataset into train/test sets
def train_test_split(data, n_test):
	return data[:-n_test], data[-n_test:]

# walk-forward validation for univariate data
def walk_forward_validation(data, n_test, cfg):
	predictions = list()
	# split dataset
	train, test = train_test_split(data, n_test)
	# seed history with training dataset
	history = [x for x in train]
	# step over each time-step in the test set
	for i in range(len(test)):
		# fit model and make forecast for history
		yhat = sarima_forecast(history, cfg)
		# store forecast in list of predictions
		predictions.append(yhat)
		# add actual observation to history for the next loop
		history.append(test[i])
	# estimate prediction error
	error = measure_rmse(test, predictions)
	return error

# score a model, return None on failure
def score_model(data, n_test, cfg, debug=False):
	result = None
	# convert config to a key
	key = str(cfg)
	# show all warnings and fail on exception if debugging
	if debug:
		result = walk_forward_validation(data, n_test, cfg)
	else:
		# one failure during model validation suggests an unstable config
		try:
			# never show warnings when grid searching, too noisy
			with catch_warnings():
				filterwarnings("ignore")
				result = walk_forward_validation(data, n_test, cfg)
		except:
			error = None
	# check for an interesting result
	if result is not None:
		print(' > Model[%s] %.3f' % (key, result))
	return (key, result)

# grid search configs
def grid_search(data, cfg_list, n_test, parallel=True):
	scores = None
	if parallel:
		# execute configs in parallel
		executor = Parallel(n_jobs=cpu_count(), backend='multiprocessing')
		tasks = (delayed(score_model)(data, n_test, cfg) for cfg in cfg_list)
		scores = executor(tasks)
	else:
		scores = [score_model(data, n_test, cfg) for cfg in cfg_list]
	# remove empty results
	scores = [r for r in scores if r[1] != None]
	# sort configs by error, asc
	scores.sort(key=lambda tup: tup[1])
	return scores

# create a set of sarima configs to try
def sarima_configs(seasonal=[0]):
	models = list()
	# define config lists
	p_params = [0, 1, 2]
	d_params = [0, 1]
	q_params = [0, 1, 2]
	t_params = ['n'] #'c','t','ct'
	P_params = [0, 1, 2]
	D_params = [0, 1]
	Q_params = [0, 1, 2]
	m_params = seasonal
	# create config instances
	for p in p_params:
		for d in d_params:
			for q in q_params:
				for t in t_params:
					for P in P_params:
						for D in D_params:
							for Q in Q_params:
								for m in m_params:
									cfg = [(p,d,q), (P,D,Q,m), t]
									models.append(cfg)
	return models

if __name__ == '__main__':
	# load dataset
	#series = read_csv('monthly-mean-temp.csv', header=0, index_col=0)
	#data = series.values
	# trim dataset to 5 years
	data = y
	# data split
	n_test = 12
	# model configs
	cfg_list = sarima_configs(seasonal=[0,12])
	# grid search
	scores = grid_search(data, cfg_list, n_test)
	print('done')
	# list top 3 configs
	for cfg, error in scores[:3]:
		print(cfg, error)
# Out:
#  > Model[[(0, 0, 0), (0, 0, 0, 0), 'n']] 515.321
#  > Model[[(0, 0, 0), (0, 1, 0, 12), 'n']] 379.545
#  > Model[[(0, 0, 0), (0, 0, 0, 12), 'n']] 515.321
#  > Model[[(0, 0, 0), (0, 0, 1, 0), 'n']] 271.264
#  > Model[[(0, 0, 0), (1, 0, 0, 0), 'n']] 96.044
#  > Model[[(0, 0, 0), (2, 0, 0, 0), 'n']] 96.497
#  > Model[[(0, 0, 1), (0, 0, 0, 0), 'n']] 271.264
#  > Model[[(0, 0, 0), (0, 0, 2, 0), 'n']] 185.762
#  > Model[[(0, 0, 0), (1, 0, 1, 0), 'n']] 94.376
#  > Model[[(0, 0, 1), (0, 0, 0, 12), 'n']] 271.264
#  > Model[[(0, 0, 0), (2, 0, 1, 0), 'n']] 87.886
#  > Model[[(0, 0, 1), (1, 0, 0, 0), 'n']] 94.588
#  > Model[[(0, 0, 1), (0, 0, 1, 0), 'n']] 182.796
#  > Model[[(0, 0, 0), (1, 0, 2, 0), 'n']] 109.405
#  > Model[[(0, 0, 1), (1, 0, 1, 0), 'n']] 104.131
#  > Model[[(0, 0, 0), (2, 0, 2, 0), 'n']] 96.560
#  > Model[[(0, 0, 1), (0, 0, 2, 0), 'n']] 142.395
#  > Model[[(0, 0, 1), (2, 0, 0, 0), 'n']] 96.113
#  > Model[[(0, 0, 2), (0, 0, 0, 0), 'n']] 185.762
# ...

# %% [markdown]
# # Zone wise data analysis

# %%
df.columns
# Out:
# Index(['CASE_ID', 'CHANNEL_NAME', 'CONTACT_OPTION', 'CUST_REGION_NAME',
#        'DIAL_SCHEDULE_TIME', 'HISTORY_DATA', 'IP_ADDRESS', 'RESULT',
#        'SCB_TIME', 'SCR_DATE', 'UUID', 'Date_SC', 'Time_SC', 'year', 'month',
#        'day', 'hour', 'Minutes', 'Seconds', 'weekday'],
#       dtype='object')

# %%
df.CUST_REGION_NAME.unique()
# Out:
# array(['ASIAPAC', 'AMERICAS', 'EUROPE', 'JAPAN', nan, 'APAC'],
#       dtype=object)

# %%
########### Zone wise analysis only for ASIAPAC, AMERICAS, EUROPE, JAPAN ################

# %%
###### for ASIA (ASIAPAC and APAC are same ) combine both ###########
df1=df[(df['CUST_REGION_NAME']=='ASIAPAC')]
print(df1.shape)
d=df[(df['CUST_REGION_NAME']=='APAC')]
print(d.shape)
df1=df1.append(d, ignore_index=False)
print(df1.shape)
# Out:
# (176559, 20)
# (1, 20)
# (176560, 20)

# %%
df1.columns
# Out:
# Index(['CASE_ID', 'CHANNEL_NAME', 'CONTACT_OPTION', 'CUST_REGION_NAME',
#        'DIAL_SCHEDULE_TIME', 'HISTORY_DATA', 'IP_ADDRESS', 'RESULT',
#        'SCB_TIME', 'SCR_DATE', 'UUID', 'Date_SC', 'Time_SC', 'year', 'month',
#        'day', 'hour', 'Minutes', 'Seconds', 'weekday'],
#       dtype='object')

# %%
df1.isnull().sum()
# Out:
# CASE_ID                   0
# CHANNEL_NAME              0
# CONTACT_OPTION            0
# CUST_REGION_NAME          0
# DIAL_SCHEDULE_TIME        0
# HISTORY_DATA              0
# IP_ADDRESS            81535
# RESULT                    0
# SCB_TIME                  0
# SCR_DATE                  0
# UUID                  30700
# Date_SC                   0
# Time_SC                   0
# year                      0
# month                     0
# day                       0
# hour                      0
# Minutes                   0
# Seconds                   0
# weekday                   0
# dtype: int64

# %%
# Count for channel name ###########

# %%
sns.countplot(x='CHANNEL_NAME',data=df1)

# %%
df1['CHANNEL_NAME'].value_counts()
# Out:
# CAS       95028
# IOSAPP    41622
# AGENT     19877
# CMA       14187
# CHAT       5662
# EMAIL       184
# Name: CHANNEL_NAME, dtype: int64

# %%
####### for making time series data analysis-> taking only feb-2019 month data ###########

# %%
#df1.Date_SC

# %%
#df1 = df1[(df1.month == 2)]

# %%
#df1.Date_SC

# %%
a4_dims = (15, 5)
fig, ax = plt.subplots(figsize=a4_dims)
y=df1['Date_SC'].resample('D').count()
y.plot()

# %%
a4_dims = (15, 5)
fig, ax = plt.subplots(figsize=a4_dims)
y=df1['day'].resample('W',closed='right',label='right').count()
print(y)
y.plot()
# Out:
# Schedule_time
# 2019-02-03    15103
# 2019-02-10    29291
# 2019-02-17    32582
# 2019-02-24    17165
# 2019-03-03       74
# 2019-03-10        0
# 2019-03-17        0
# 2019-03-24        0
# 2019-03-31    24656
# 2019-04-07    30507
# 2019-04-14    24667
# 2019-04-21     2492
# 2019-04-28       23
# Freq: W-SUN, Name: day, dtype: int64

# %%
a4_dims = (15, 5)
fig, ax = plt.subplots(figsize=a4_dims)
y=df1['Time_SC'].resample('H').count()
print(y)
y.plot()
# Out:
# Schedule_time
# 2019-01-30 18:00:00      1
# 2019-01-30 19:00:00      0
# 2019-01-30 20:00:00     11
# 2019-01-30 21:00:00      4
# 2019-01-30 22:00:00     23
# 2019-01-30 23:00:00     21
# 2019-01-31 00:00:00     59
# 2019-01-31 01:00:00    421
# 2019-01-31 02:00:00    310
# 2019-01-31 03:00:00    208
# 2019-01-31 04:00:00    218
# 2019-01-31 05:00:00    208
# 2019-01-31 06:00:00    195
# 2019-01-31 07:00:00    198
# 2019-01-31 08:00:00    195
# 2019-01-31 09:00:00    143
# 2019-01-31 10:00:00    134
# 2019-01-31 11:00:00    177
# 2019-01-31 12:00:00      7
# 2019-01-31 13:00:00      4
# 2019-01-31 14:00:00      2
# 2019-01-31 15:00:00      0
# 2019-01-31 16:00:00      2
# 2019-01-31 17:00:00      0
# 2019-01-31 18:00:00      3
# 2019-01-31 19:00:00      0
# 2019-01-31 20:00:00     37
# 2019-01-31 21:00:00      9
# 2019-01-31 22:00:00     95
# 2019-01-31 23:00:00     80
#                       ...
# 2019-04-25 01:00:00      0
# 2019-04-25 02:00:00      0
# ...

# %%
a4_dims = (15, 5)
fig, ax = plt.subplots(figsize=a4_dims)
y=df1['Time_SC'].resample('H').count()
y=y['2019-02-01 00:00:00':'2019-02-01 23:00:00']
print(y)
y.plot()
# Out:
# Schedule_time
# 2019-02-01 00:00:00     134
# 2019-02-01 01:00:00    1145
# 2019-02-01 02:00:00     807
# 2019-02-01 03:00:00     505
# 2019-02-01 04:00:00     427
# 2019-02-01 05:00:00     335
# 2019-02-01 06:00:00     312
# 2019-02-01 07:00:00     245
# 2019-02-01 08:00:00     211
# 2019-02-01 09:00:00     150
# 2019-02-01 10:00:00     108
# 2019-02-01 11:00:00     163
# 2019-02-01 12:00:00       6
# 2019-02-01 13:00:00      10
# 2019-02-01 14:00:00       1
# 2019-02-01 15:00:00       0
# 2019-02-01 16:00:00       2
# 2019-02-01 17:00:00       2
# 2019-02-01 18:00:00       1
# 2019-02-01 19:00:00       0
# 2019-02-01 20:00:00      27
# 2019-02-01 21:00:00      10
# 2019-02-01 22:00:00      86
# 2019-02-01 23:00:00      91
# Freq: H, Name: Time_SC, dtype: int64

# %%
###### for AMERICA ###########
df2=df[df['CUST_REGION_NAME']=='AMERICAS']
df2.shape
# Out:
# (525305, 20)

# %%
df2.isnull().sum()
# Out:
# CASE_ID                    0
# CHANNEL_NAME               0
# CONTACT_OPTION             0
# CUST_REGION_NAME           0
# DIAL_SCHEDULE_TIME         0
# HISTORY_DATA               0
# IP_ADDRESS            408901
# RESULT                     0
# SCB_TIME                   0
# SCR_DATE                   0
# UUID                  285898
# Date_SC                    0
# Time_SC                    0
# year                       0
# month                      0
# day                        0
# hour                       0
# Minutes                    0
# Seconds                    0
# weekday                    0
# dtype: int64

# %%
sns.countplot(x='CHANNEL_NAME',data=df2)

# %%
df2['CHANNEL_NAME'].value_counts()
# Out:
# AGENT     234877
# CAS       116427
# CMA        90297
# IOSAPP     42700
# CHAT       39279
# EMAIL       1725
# Name: CHANNEL_NAME, dtype: int64

# %%
####### for making time series data analysis-> taking only feb-2019 month data ###########
#df2=df2[df2.month==2]

# %%
a4_dims = (15, 5)
fig, ax = plt.subplots(figsize=a4_dims)
y=df2['Date_SC'].resample('D').count()
print(y)
y.plot()
# Out:
# Schedule_time
# 2019-01-30     3448
# 2019-01-31    12238
# 2019-02-01    14312
# 2019-02-02    12657
# 2019-02-03    10619
# 2019-02-04    12771
# 2019-02-05    13826
# 2019-02-06    13400
# 2019-02-07    13502
# 2019-02-08    13661
# 2019-02-09    13245
# 2019-02-10    10845
# 2019-02-11    13774
# 2019-02-12    13737
# 2019-02-13    13128
# 2019-02-14    12249
# 2019-02-15    12440
# 2019-02-16    12210
# 2019-02-17    10236
# 2019-02-18    14027
# 2019-02-19    13380
# 2019-02-20    13011
# 2019-02-21     3442
# 2019-02-22      803
# 2019-02-23      454
# 2019-02-24      140
# 2019-02-25      144
# 2019-02-26       75
# 2019-02-27       31
# 2019-02-28        7
#               ...
# 2019-03-29    12025
# 2019-03-30    10620
# 2019-03-31     9482
# 2019-04-01    12874
# 2019-04-02    12700
# 2019-04-03    12665
# 2019-04-04    12614
# 2019-04-05    12507
# 2019-04-06    10767
# 2019-04-07     9057
# 2019-04-08    12322
# 2019-04-09    12401
# 2019-04-10    12028
# ...

# %%
a4_dims = (15, 5)
fig, ax = plt.subplots(figsize=a4_dims)
y=df2['Date_SC'].resample('W',closed='right',label='right').count()
print(y)
y.plot()
# Out:
# Schedule_time
# 2019-02-03    53274
# 2019-02-10    91250
# 2019-02-17    87774
# 2019-02-24    45257
# 2019-03-03      282
# 2019-03-10        0
# 2019-03-17        0
# 2019-03-24        0
# 2019-03-31    87028
# 2019-04-07    83184
# 2019-04-14    71520
# 2019-04-21     5725
# 2019-04-28       11
# Freq: W-SUN, Name: Date_SC, dtype: int64

# %%
a4_dims = (15, 5)
fig, ax = plt.subplots(figsize=a4_dims)
y=df2['Time_SC'].resample('H').count()
print(y)
y.plot()
# Out:
# Schedule_time
# 2019-01-30 18:00:00    103
# 2019-01-30 19:00:00    483
# 2019-01-30 20:00:00    641
# 2019-01-30 21:00:00    690
# 2019-01-30 22:00:00    754
# 2019-01-30 23:00:00    777
# 2019-01-31 00:00:00    822
# 2019-01-31 01:00:00    766
# 2019-01-31 02:00:00    679
# 2019-01-31 03:00:00    208
# 2019-01-31 04:00:00     10
# 2019-01-31 05:00:00      5
# 2019-01-31 06:00:00     15
# 2019-01-31 07:00:00     22
# 2019-01-31 08:00:00     34
# 2019-01-31 09:00:00     32
# 2019-01-31 10:00:00    111
# 2019-01-31 11:00:00    138
# 2019-01-31 12:00:00    101
# 2019-01-31 13:00:00    733
# 2019-01-31 14:00:00    626
# 2019-01-31 15:00:00    726
# 2019-01-31 16:00:00    859
# 2019-01-31 17:00:00    837
# 2019-01-31 18:00:00    848
# 2019-01-31 19:00:00    840
# 2019-01-31 20:00:00    951
# 2019-01-31 21:00:00    982
# 2019-01-31 22:00:00    961
# 2019-01-31 23:00:00    932
#                       ...
# 2019-04-26 18:00:00      0
# 2019-04-26 19:00:00      0
# ...

# %%
a4_dims = (15, 5)
fig, ax = plt.subplots(figsize=a4_dims)
y=df2['Time_SC'].resample('H').count()
y=y['2019-02-01 00:00:00':'2019-02-01 23:00:00']
print(y)
y.plot()
# Out:
# Schedule_time
# 2019-02-01 00:00:00     991
# 2019-02-01 01:00:00     913
# 2019-02-01 02:00:00     885
# 2019-02-01 03:00:00     327
# 2019-02-01 04:00:00      12
# 2019-02-01 05:00:00      19
# 2019-02-01 06:00:00      22
# 2019-02-01 07:00:00      31
# 2019-02-01 08:00:00      57
# 2019-02-01 09:00:00      41
# 2019-02-01 10:00:00     132
# 2019-02-01 11:00:00     122
# 2019-02-01 12:00:00     114
# 2019-02-01 13:00:00     770
# 2019-02-01 14:00:00     835
# 2019-02-01 15:00:00     907
# 2019-02-01 16:00:00     949
# 2019-02-01 17:00:00     998
# 2019-02-01 18:00:00    1010
# 2019-02-01 19:00:00     994
# 2019-02-01 20:00:00    1022
# 2019-02-01 21:00:00    1057
# 2019-02-01 22:00:00    1094
# 2019-02-01 23:00:00    1010
# Freq: H, Name: Time_SC, dtype: int64

# %%
###### for EUROPE ###########
df3=df[df['CUST_REGION_NAME']== 'EUROPE']
df3.shape
# Out:
# (266148, 20)

# %%
#df3=df3[df3.month==2]

# %%
df3.isnull().sum()
# Out:
# CASE_ID                    0
# CHANNEL_NAME               0
# CONTACT_OPTION             0
# CUST_REGION_NAME           0
# DIAL_SCHEDULE_TIME         0
# HISTORY_DATA               1
# IP_ADDRESS            140405
# RESULT                     0
# SCB_TIME                   0
# SCR_DATE                   0
# UUID                   73420
# Date_SC                    0
# Time_SC                    0
# year                       0
# month                      0
# day                        0
# hour                       0
# Minutes                    0
# Seconds                    0
# weekday                    0
# dtype: int64

# %%
sns.countplot(x='CHANNEL_NAME',data=df3)

# %%
a4_dims = (15, 5)
fig, ax = plt.subplots(figsize=a4_dims)
y=df3['Date_SC'].resample('D').count()
print(y)
y.plot()
# Out:
# Schedule_time
# 2019-01-30       15
# 2019-01-31     6951
# 2019-02-01     7302
# 2019-02-02     6211
# 2019-02-03     5109
# 2019-02-04     7262
# 2019-02-05     7420
# 2019-02-06     7279
# 2019-02-07     6925
# 2019-02-08     6795
# 2019-02-09     6245
# 2019-02-10     5121
# 2019-02-11     7330
# 2019-02-12     7250
# 2019-02-13     6898
# 2019-02-14     6448
# 2019-02-15     6227
# 2019-02-16     5603
# 2019-02-17     4618
# 2019-02-18     7013
# 2019-02-19     7024
# 2019-02-20     6917
# 2019-02-21     3473
# 2019-02-22      432
# 2019-02-23      302
# 2019-02-24       97
# 2019-02-25       84
# 2019-02-26       36
# 2019-02-27       20
# 2019-02-28        3
#               ...
# 2019-03-26    10172
# 2019-03-27     8889
# 2019-03-28     6394
# 2019-03-29     5929
# 2019-03-30     5024
# 2019-03-31     3816
# 2019-04-01     6258
# 2019-04-02     6209
# 2019-04-03     6552
# 2019-04-04     6310
# 2019-04-05     6165
# 2019-04-06     5210
# 2019-04-07     4258
# ...

# %%
a4_dims = (15, 5)
fig, ax = plt.subplots(figsize=a4_dims)
y=df3['Date_SC'].resample('W',closed='right',label='right').count()
print(y)
y.plot()
# Out:
# Schedule_time
# 2019-02-03    25588
# 2019-02-10    47047
# 2019-02-17    44374
# 2019-02-24    25258
# 2019-03-03      150
# 2019-03-10        0
# 2019-03-17        0
# 2019-03-24        0
# 2019-03-31    40256
# 2019-04-07    40962
# 2019-04-14    39559
# 2019-04-21     2941
# 2019-04-28       13
# Freq: W-SUN, Name: Date_SC, dtype: int64

# %%
a4_dims = (15, 5)
fig, ax = plt.subplots(figsize=a4_dims)
y=df3['Time_SC'].resample('H').count()
print(y)
y.plot()
# Out:
# Schedule_time
# 2019-01-30 18:00:00       7
# 2019-01-30 19:00:00       2
# 2019-01-30 20:00:00       2
# 2019-01-30 21:00:00       2
# 2019-01-30 22:00:00       0
# 2019-01-30 23:00:00       2
# 2019-01-31 00:00:00       0
# 2019-01-31 01:00:00       8
# 2019-01-31 02:00:00       1
# 2019-01-31 03:00:00      17
# 2019-01-31 04:00:00      20
# 2019-01-31 05:00:00     113
# 2019-01-31 06:00:00      90
# 2019-01-31 07:00:00     385
# 2019-01-31 08:00:00     598
# 2019-01-31 09:00:00     822
# 2019-01-31 10:00:00    1036
# 2019-01-31 11:00:00     724
# 2019-01-31 12:00:00     535
# 2019-01-31 13:00:00     501
# 2019-01-31 14:00:00     469
# 2019-01-31 15:00:00     484
# 2019-01-31 16:00:00     488
# 2019-01-31 17:00:00     501
# 2019-01-31 18:00:00     139
# 2019-01-31 19:00:00      14
# 2019-01-31 20:00:00       3
# 2019-01-31 21:00:00       2
# 2019-01-31 22:00:00       0
# 2019-01-31 23:00:00       1
#                        ...
# 2019-04-23 03:00:00       0
# ...

# %%
a4_dims = (15, 5)
fig, ax = plt.subplots(figsize=a4_dims)
y=df3['Time_SC'].resample('H').count()
y=y['2019-02-01 00:00:00':'2019-02-01 23:00:00']
print(y)
y.plot()
# Out:
# Schedule_time
# 2019-02-01 00:00:00      2
# 2019-02-01 01:00:00      1
# 2019-02-01 02:00:00      2
# 2019-02-01 03:00:00     29
# 2019-02-01 04:00:00     61
# 2019-02-01 05:00:00    169
# 2019-02-01 06:00:00    157
# 2019-02-01 07:00:00    505
# 2019-02-01 08:00:00    775
# 2019-02-01 09:00:00    816
# 2019-02-01 10:00:00    737
# 2019-02-01 11:00:00    641
# 2019-02-01 12:00:00    574
# 2019-02-01 13:00:00    527
# 2019-02-01 14:00:00    570
# 2019-02-01 15:00:00    512
# 2019-02-01 16:00:00    534
# 2019-02-01 17:00:00    471
# 2019-02-01 18:00:00    202
# 2019-02-01 19:00:00      8
# 2019-02-01 20:00:00      4
# 2019-02-01 21:00:00      0
# 2019-02-01 22:00:00      3
# 2019-02-01 23:00:00      2
# Freq: H, Name: Time_SC, dtype: int64

# %%
###### for JAPAN ###########
df4=df[df['CUST_REGION_NAME']== 'JAPAN']
df4.shape
# Out:
# (42025, 20)

# %%
#df4=df4[df4.month==2]

# %%
df4.shape
# Out:
# (42025, 20)

# %%
df4.isnull().sum()
# Out:
# CASE_ID                   0
# CHANNEL_NAME              0
# CONTACT_OPTION            0
# CUST_REGION_NAME          0
# DIAL_SCHEDULE_TIME        0
# HISTORY_DATA              0
# IP_ADDRESS            16881
# RESULT                    0
# SCB_TIME                  0
# SCR_DATE                  0
# UUID                   9809
# Date_SC                   0
# Time_SC                   0
# year                      0
# month                     0
# day                       0
# hour                      0
# Minutes                   0
# Seconds                   0
# weekday                   0
# dtype: int64

# %%
df4.CHANNEL_NAME.unique()
# Out:
# array(['IOSAPP', 'CAS', 'AGENT', 'CHAT', 'CMA', 'EMAIL'], dtype=object)

# %%
sns.countplot(x='CHANNEL_NAME',data=df4)

# %%
a4_dims = (15, 5)
fig, ax = plt.subplots(figsize=a4_dims)
y=df4['Date_SC'].resample('D').count()
print(y)
y.plot()
# Out:
# Schedule_time
# 2019-01-31     512
# 2019-02-01    1050
# 2019-02-02    1156
# 2019-02-03    1158
# 2019-02-04    1237
# 2019-02-05    1043
# 2019-02-06    1001
# 2019-02-07     954
# 2019-02-08     908
# 2019-02-09    1033
# 2019-02-10    1028
# 2019-02-11    1216
# 2019-02-12    1047
# 2019-02-13     959
# 2019-02-14     998
# 2019-02-15     897
# 2019-02-16    1036
# 2019-02-17    1038
# 2019-02-18    1117
# 2019-02-19     959
# 2019-02-20     923
# 2019-02-21     709
# 2019-02-22     132
# 2019-02-23     104
# 2019-02-24      43
# 2019-02-25      10
# 2019-02-26       4
# 2019-02-27       2
# 2019-02-28       0
# 2019-03-01       0
#               ...
# 2019-03-24       0
# 2019-03-25       0
# 2019-03-26     950
# 2019-03-27    1320
# 2019-03-28    1017
# 2019-03-29     933
# 2019-03-30    1019
# 2019-03-31    1095
# 2019-04-01    1048
# 2019-04-02    1030
# 2019-04-03     954
# 2019-04-04     930
# 2019-04-05     864
# 2019-04-06     980
# 2019-04-07    1004
# ...

# %%
a4_dims = (15, 5)
fig, ax = plt.subplots(figsize=a4_dims)
y=df4['Date_SC'].resample('W',closed='right',label='right').count()
print(y)
y.plot()
# Out:
# Schedule_time
# 2019-02-03    3876
# 2019-02-10    7204
# 2019-02-17    7191
# 2019-02-24    3987
# 2019-03-03      16
# 2019-03-10       0
# 2019-03-17       0
# 2019-03-24       0
# 2019-03-31    6334
# 2019-04-07    6810
# 2019-04-14    6130
# 2019-04-21     475
# 2019-04-28       2
# Freq: W-SUN, Name: Date_SC, dtype: int64

# %%
a4_dims = (15, 5)
fig, ax = plt.subplots(figsize=a4_dims)
y=df4['Time_SC'].resample('H').count()
print(y)
y.plot()
# Out:
# Schedule_time
# 2019-01-31 00:00:00     96
# 2019-01-31 01:00:00     34
# 2019-01-31 02:00:00     36
# 2019-01-31 03:00:00     42
# 2019-01-31 04:00:00     35
# 2019-01-31 05:00:00     25
# 2019-01-31 06:00:00     32
# 2019-01-31 07:00:00     48
# 2019-01-31 08:00:00     43
# 2019-01-31 09:00:00     60
# 2019-01-31 10:00:00     54
# 2019-01-31 11:00:00      5
# 2019-01-31 12:00:00      0
# 2019-01-31 13:00:00      0
# 2019-01-31 14:00:00      0
# 2019-01-31 15:00:00      1
# 2019-01-31 16:00:00      0
# 2019-01-31 17:00:00      0
# 2019-01-31 18:00:00      0
# 2019-01-31 19:00:00      0
# 2019-01-31 20:00:00      0
# 2019-01-31 21:00:00      0
# 2019-01-31 22:00:00      0
# 2019-01-31 23:00:00      1
# 2019-02-01 00:00:00    216
# 2019-02-01 01:00:00    141
# 2019-02-01 02:00:00     83
# 2019-02-01 03:00:00    119
# 2019-02-01 04:00:00     85
# 2019-02-01 05:00:00     48
#                       ...
# 2019-04-20 22:00:00      0
# 2019-04-20 23:00:00      0
# ...

# %%
a4_dims = (15, 5)
fig, ax = plt.subplots(figsize=a4_dims)
y=df4['Time_SC'].resample('H').count()
y=y['2019-02-01 00:00:00':'2019-02-01 23:00:00']
print(y)
y.plot()
# Out:
# Schedule_time
# 2019-02-01 00:00:00    216
# 2019-02-01 01:00:00    141
# 2019-02-01 02:00:00     83
# 2019-02-01 03:00:00    119
# 2019-02-01 04:00:00     85
# 2019-02-01 05:00:00     48
# 2019-02-01 06:00:00     52
# 2019-02-01 07:00:00     48
# 2019-02-01 08:00:00     60
# 2019-02-01 09:00:00     75
# 2019-02-01 10:00:00    116
# 2019-02-01 11:00:00      5
# 2019-02-01 12:00:00      0
# 2019-02-01 13:00:00      0
# 2019-02-01 14:00:00      0
# 2019-02-01 15:00:00      1
# 2019-02-01 16:00:00      1
# 2019-02-01 17:00:00      0
# 2019-02-01 18:00:00      0
# 2019-02-01 19:00:00      0
# 2019-02-01 20:00:00      0
# 2019-02-01 21:00:00      0
# 2019-02-01 22:00:00      0
# 2019-02-01 23:00:00      0
# Freq: H, Name: Time_SC, dtype: int64

# %%
########### IP Address to country conversion ################
########## If I get this its easy to go forward #########
######### HAVE TO DO YET ################

# %% [markdown]
# #  analyzing based on channel Name ########

# %%
df.CHANNEL_NAME.unique()
# Out:
# array(['CAS', 'CHAT', 'AGENT', 'IOSAPP', 'CMA', 'EMAIL'], dtype=object)

# %%
d1=df[df.CHANNEL_NAME=='CAS']
d1.shape
# Out:
# (362445, 20)

# %%
sns.countplot(x='CUST_REGION_NAME',data=d1)

# %%
a4_dims = (15, 5)
fig, ax = plt.subplots(figsize=a4_dims)
y=d1['Date_SC'].resample('D').count()
y=y['2019-02-01':'2019-02-28']
print(y)
y.plot()
# Out:
# Schedule_time
# 2019-02-01     9712
# 2019-02-02     8773
# 2019-02-03     7228
# 2019-02-04     7810
# 2019-02-05     7772
# 2019-02-06    12005
# 2019-02-07    11022
# 2019-02-08     9263
# 2019-02-09     8708
# 2019-02-10     7256
# 2019-02-11    10022
# 2019-02-12     9225
# 2019-02-13     8756
# 2019-02-14     8662
# 2019-02-15     8789
# 2019-02-16     8376
# 2019-02-17     7183
# 2019-02-18     9780
# 2019-02-19     9082
# 2019-02-20     8912
# 2019-02-21     4960
# 2019-02-22      606
# 2019-02-23      448
# 2019-02-24      168
# 2019-02-25       83
# 2019-02-26       30
# 2019-02-27        5
# 2019-02-28        0
# Freq: D, Name: Date_SC, dtype: int64

# %%
#d1=d1[d1.month==2]

# %%
a4_dims = (15, 5)
fig, ax = plt.subplots(figsize=a4_dims)
y=d1['Date_SC'].resample('W',closed='right',label='right').count()
print(y)
y.plot()
# Out:
# Schedule_time
# 2019-02-03    33959
# 2019-02-10    63836
# 2019-02-17    61013
# 2019-02-24    33956
# 2019-03-03      118
# 2019-03-10        0
# 2019-03-17        0
# 2019-03-24        0
# 2019-03-31    53872
# 2019-04-07    58309
# 2019-04-14    53158
# 2019-04-21     4217
# 2019-04-28        7
# Freq: W-SUN, Name: Date_SC, dtype: int64

# %%
a4_dims = (15, 5)
fig, ax = plt.subplots(figsize=a4_dims)
y=d1['Time_SC'].resample('H').count()
print(y)
y.plot()
# Out:
# Schedule_time
# 2019-01-30 18:00:00     28
# 2019-01-30 19:00:00     81
# 2019-01-30 20:00:00     91
# 2019-01-30 21:00:00     79
# 2019-01-30 22:00:00     86
# 2019-01-30 23:00:00    104
# 2019-01-31 00:00:00    201
# 2019-01-31 01:00:00    402
# 2019-01-31 02:00:00    240
# 2019-01-31 03:00:00    146
# 2019-01-31 04:00:00    126
# 2019-01-31 05:00:00    137
# 2019-01-31 06:00:00    141
# 2019-01-31 07:00:00    335
# 2019-01-31 08:00:00    452
# 2019-01-31 09:00:00    611
# 2019-01-31 10:00:00    780
# 2019-01-31 11:00:00    524
# 2019-01-31 12:00:00    320
# 2019-01-31 13:00:00    632
# 2019-01-31 14:00:00    418
# 2019-01-31 15:00:00    406
# 2019-01-31 16:00:00    417
# 2019-01-31 17:00:00    413
# 2019-01-31 18:00:00    294
# 2019-01-31 19:00:00    162
# 2019-01-31 20:00:00    190
# 2019-01-31 21:00:00    134
# 2019-01-31 22:00:00    132
# 2019-01-31 23:00:00    164
#                       ...
# 2019-04-21 10:00:00      0
# 2019-04-21 11:00:00      0
# ...

# %%
a4_dims = (15, 5)
fig, ax = plt.subplots(figsize=a4_dims)
y=d1['Time_SC'].resample('H').count()
y=y['2019-02-01 00:00:00':'2019-02-15 23:00:00']
print(y)
y.plot()
# Out:
# Schedule_time
# 2019-02-01 00:00:00    398
# 2019-02-01 01:00:00    898
# 2019-02-01 02:00:00    633
# 2019-02-01 03:00:00    444
# 2019-02-01 04:00:00    319
# 2019-02-01 05:00:00    296
# 2019-02-01 06:00:00    258
# 2019-02-01 07:00:00    423
# 2019-02-01 08:00:00    544
# 2019-02-01 09:00:00    525
# 2019-02-01 10:00:00    514
# 2019-02-01 11:00:00    421
# 2019-02-01 12:00:00    295
# 2019-02-01 13:00:00    613
# 2019-02-01 14:00:00    545
# 2019-02-01 15:00:00    440
# 2019-02-01 16:00:00    445
# 2019-02-01 17:00:00    410
# 2019-02-01 18:00:00    339
# 2019-02-01 19:00:00    224
# 2019-02-01 20:00:00    173
# 2019-02-01 21:00:00    160
# 2019-02-01 22:00:00    210
# 2019-02-01 23:00:00    185
# 2019-02-02 00:00:00    369
# 2019-02-02 01:00:00    839
# 2019-02-02 02:00:00    654
# 2019-02-02 03:00:00    456
# 2019-02-02 04:00:00    273
# 2019-02-02 05:00:00    299
#                       ...
# 2019-02-14 18:00:00    236
# 2019-02-14 19:00:00    144
# ...

# %%
d2=df[df.CHANNEL_NAME=='IOSAPP']
d2.shape
# Out:
# (136694, 20)

# %%
#d2=d2[d2.month==2]

# %%
sns.countplot(x='CUST_REGION_NAME',data=d2)

# %%
a4_dims = (15, 5)
fig, ax = plt.subplots(figsize=a4_dims)
y=d2['Date_SC'].resample('D').count()
y=y['2019-02-01':'2019-02-28']
print(y)
y.plot()
# Out:
# Schedule_time
# 2019-02-01    3624
# 2019-02-02    3296
# 2019-02-03    2722
# 2019-02-04    2746
# 2019-02-05    2614
# 2019-02-06    3917
# 2019-02-07    3768
# 2019-02-08    3368
# 2019-02-09    3092
# 2019-02-10    2778
# 2019-02-11    3780
# 2019-02-12    3593
# 2019-02-13    3469
# 2019-02-14    3357
# 2019-02-15    3464
# 2019-02-16    3321
# 2019-02-17    2909
# 2019-02-18    3804
# 2019-02-19    3688
# 2019-02-20    3592
# 2019-02-21    1207
# 2019-02-22      80
# 2019-02-23      47
# 2019-02-24      14
# 2019-02-25       9
# 2019-02-26       2
# 2019-02-27       0
# 2019-02-28       0
# Freq: D, Name: Date_SC, dtype: int64

# %%
a4_dims = (15, 5)
fig, ax = plt.subplots(figsize=a4_dims)
y=d2['Date_SC'].resample('W',closed='right',label='right').count()
print(y)
y.plot()
# Out:
# Schedule_time
# 2019-02-03    12889
# 2019-02-10    22283
# 2019-02-17    23893
# 2019-02-24    12432
# 2019-03-03       11
# 2019-03-10        0
# 2019-03-17        0
# 2019-03-24        0
# 2019-03-31    21293
# 2019-04-07    23410
# 2019-04-14    19182
# 2019-04-21     1301
# Freq: W-SUN, Name: Date_SC, dtype: int64

# %%
a4_dims = (15, 5)
fig, ax = plt.subplots(figsize=a4_dims)
y=d2['Time_SC'].resample('H').count()
print(y)
y.plot()
# Out:
# Schedule_time
# 2019-01-30 18:00:00     19
# 2019-01-30 19:00:00     55
# 2019-01-30 20:00:00     70
# 2019-01-30 21:00:00     52
# 2019-01-30 22:00:00     62
# 2019-01-30 23:00:00     50
# 2019-01-31 00:00:00     68
# 2019-01-31 01:00:00    186
# 2019-01-31 02:00:00    155
# 2019-01-31 03:00:00     69
# 2019-01-31 04:00:00     53
# 2019-01-31 05:00:00     76
# 2019-01-31 06:00:00     64
# 2019-01-31 07:00:00    127
# 2019-01-31 08:00:00    169
# 2019-01-31 09:00:00    217
# 2019-01-31 10:00:00    247
# 2019-01-31 11:00:00    178
# 2019-01-31 12:00:00    105
# 2019-01-31 13:00:00    147
# 2019-01-31 14:00:00    178
# 2019-01-31 15:00:00    181
# 2019-01-31 16:00:00    160
# 2019-01-31 17:00:00    118
# 2019-01-31 18:00:00     76
# 2019-01-31 19:00:00     74
# 2019-01-31 20:00:00     74
# 2019-01-31 21:00:00     70
# 2019-01-31 22:00:00     83
# 2019-01-31 23:00:00     64
#                       ...
# 2019-04-19 22:00:00      0
# 2019-04-19 23:00:00      0
# ...

# %%
a4_dims = (15, 5)
fig, ax = plt.subplots(figsize=a4_dims)
y=d2['Time_SC'].resample('H').count()
y=y['2019-02-01 00:00:00':'2019-02-15 23:00:00']
y.plot()

# %%
d3=df[df.CHANNEL_NAME=='AGENT']
d3.shape
# Out:
# (312231, 20)

# %%
#d3=d3[d3.month==2]

# %%
sns.countplot(x='CUST_REGION_NAME',data=d3)

# %%
a4_dims = (15, 5)
fig, ax = plt.subplots(figsize=a4_dims)
y=d3['Date_SC'].resample('D').count()
y=y['2019-02-01':'2019-02-28']
print(y)
y.plot()
# Out:
# Schedule_time
# 2019-02-01    9439
# 2019-02-02    7481
# 2019-02-03    6103
# 2019-02-04    7406
# 2019-02-05    7950
# 2019-02-06    8204
# 2019-02-07    8603
# 2019-02-08    8310
# 2019-02-09    7636
# 2019-02-10    6108
# 2019-02-11    8348
# 2019-02-12    8611
# 2019-02-13    8264
# 2019-02-14    7801
# 2019-02-15    7626
# 2019-02-16    6899
# 2019-02-17    5666
# 2019-02-18    8029
# 2019-02-19    7876
# 2019-02-20    7896
# 2019-02-21    2085
# 2019-02-22     283
# 2019-02-23     169
# 2019-02-24      58
# 2019-02-25      61
# 2019-02-26      33
# 2019-02-27       6
# 2019-02-28       0
# Freq: D, Name: Date_SC, dtype: int64

# %%
a4_dims = (15, 5)
fig, ax = plt.subplots(figsize=a4_dims)
y=d3['Date_SC'].resample('W',closed='right',label='right').count()
print(y)
y.plot()
# Out:
# Schedule_time
# 2019-02-03    33041
# 2019-02-10    54217
# 2019-02-17    53215
# 2019-02-24    26396
# 2019-03-03      100
# 2019-03-10        0
# 2019-03-17        0
# 2019-03-24        0
# 2019-03-31    51793
# 2019-04-07    48532
# 2019-04-14    41852
# 2019-04-21     3076
# 2019-04-28        9
# Freq: W-SUN, Name: Date_SC, dtype: int64

# %%
a4_dims = (15, 5)
fig, ax = plt.subplots(figsize=a4_dims)
y=d3['Time_SC'].resample('H').count()
#y=y['2019-02-01 00:00:00':'2019-02-15 23:00:00']
y.plot()

# %%
a4_dims = (15, 5)
fig, ax = plt.subplots(figsize=a4_dims)
y=d3['Time_SC'].resample('H').count()
y=y['2019-02-01 00:00:00':'2019-02-08 23:00:00']
y.plot()

# %%
d4=df[df.CHANNEL_NAME=='CMA']
d4.shape
# Out:
# (136491, 20)

# %%
#d4=d4[d4.month==2]

# %%
sns.countplot(x='CUST_REGION_NAME',data=d4)

# %%
a4_dims = (15, 5)
fig, ax = plt.subplots(figsize=a4_dims)
y=d4['Date_SC'].resample('D').count()
y=y['2019-02-01':'2019-02-28']
print(y)
y.plot()
# Out:
# Schedule_time
# 2019-02-01    3035
# 2019-02-02    3243
# 2019-02-03    3310
# 2019-02-04    3470
# 2019-02-05    3561
# 2019-02-06    3279
# 2019-02-07    3222
# 2019-02-08    3506
# 2019-02-09    3620
# 2019-02-10    3347
# 2019-02-11    3573
# 2019-02-12    3400
# 2019-02-13    3218
# 2019-02-14    3150
# 2019-02-15    3221
# 2019-02-16    3474
# 2019-02-17    3256
# 2019-02-18    3959
# 2019-02-19    3614
# 2019-02-20    3277
# 2019-02-21    1483
# 2019-02-22     579
# 2019-02-23     323
# 2019-02-24      93
# 2019-02-25     114
# 2019-02-26      67
# 2019-02-27      46
# 2019-02-28      10
# Freq: D, Name: Date_SC, dtype: int64

# %%
a4_dims = (15, 5)
fig, ax = plt.subplots(figsize=a4_dims)
y=d2['Date_SC'].resample('W',closed='right',label='right').count()
print(y)
y.plot()
# Out:
# Schedule_time
# 2019-02-03    12889
# 2019-02-10    22283
# 2019-02-17    23893
# 2019-02-24    12432
# 2019-03-03       11
# 2019-03-10        0
# 2019-03-17        0
# 2019-03-24        0
# 2019-03-31    21293
# 2019-04-07    23410
# 2019-04-14    19182
# 2019-04-21     1301
# Freq: W-SUN, Name: Date_SC, dtype: int64

# %%
a4_dims = (15, 5)
fig, ax = plt.subplots(figsize=a4_dims)
y=d3['Time_SC'].resample('H').count()
#y=y['2019-02-01 00:00:00':'2019-02-15 23:00:00']
y.plot()

# %%
a4_dims = (15, 5)
fig, ax = plt.subplots(figsize=a4_dims)
y=d3['Time_SC'].resample('H').count()
y=y['2019-02-01 00:00:00':'2019-02-01 23:00:00']
y.plot()

# %%
d5=df[df.CHANNEL_NAME=='EMAIL']
d5.shape
# Out:
# (2848, 20)
